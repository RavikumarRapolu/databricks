# %%
# %sql
use catalog dev;

# %%
# %sql
use schema ravi;

# %%
# %sql
select * from dev.ravi.tbl1

# %%
# %sql
create table dev.ravi.tbl1 (id int, name string);
insert into dev.ravi.tbl1 values (1,'ravi'),(2,'kumar')

# %%
# %sql
Create volume dev.ravi.vol_test

# %%
df = spark.read.csv("/Volumes/dev/ravi/vol_test/sample.csv",header=True,inferSchema=True)

# %%
df.show(20,False)
#df.groupBy("deptName").sum("amount").withColumnRenamed("sum(amount)","deptAmount").write.saveAsTable("dev.ravi.deptAmount");
select * from dev.ravi.deptAmount

# %%
# %sql
select * from  dev.ravi.deptAmount

# %%
# %sql
import path
select * from read_parquet('/Volumes/dev/naval/raw/part-00000-7951754c-3166-4cb7-8227-a5760c654c14-c000.snappy.parquet')

# %%
# %sql
Create or replace function dev.ravi.getState(amount decimal) returns string  
return case when amount>100 then 'High' when amount >50 and amount <100 then 'Medium' else 'Low' end

# %%
# %sql
select Name,net_worth_in_billions,dev.ravi.getState(net_worth_in_billions) from dev.naval.richest_people
