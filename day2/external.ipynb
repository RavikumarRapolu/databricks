-- %%
create table dev.ravi.external_demo (id int, name string) location 's3://jpmbspanlabs/external/ravi/demo'

-- %%
CREATE or replace TABLE dev.ravi.emp_iceberg 
(id int, name string)
TBLPROPERTIES(
  'delta.columnMapping.mode' = 'name',
  'delta.enableIcebergCompatV2' = 'true',
  'delta.universalFormat.enabledFormats' = 'iceberg')
  location 's3://jpmbspanlabs/external/ravi/empiceberg'

;
