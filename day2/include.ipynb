-- %%
%sql
create schema if not exists dev.ravi_bronze;
create schema if not exists dev.ravi_silver;
create schema if not exists dev.ravi_gold;

-- %%
%python
input_files="/Volumes/dev/default/task";

-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
def addEtlTimeStamp(df):
  return df.withColumn("ETL_TS",current_timestamp())
